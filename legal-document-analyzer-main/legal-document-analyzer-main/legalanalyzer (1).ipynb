# %%
# CELL 1 —

# !pip install pdfplumber -q          # PDF text extraction
# !pip install pymupdf -q             # Alternative PDF reader
# !pip install python-docx -q         # DOCX file reading
# !pip install spacy -q               # NLP and NER
# !pip install transformers -q        # BERT and other models
# !pip install sentence-transformers -q  # Text embeddings
# !pip install chromadb -q            # Vector database
# !pip install langchain -q           # LLM chaining
# !pip install langchain-community -q # LangChain extras
# !pip install anthropic -q           # Claude API
# !pip install fpdf2 -q               # PDF report generation
# !pip install streamlit -q           # UI framework
# !pip install pyngrok -q             # Expose Colab to browser
# !pip install datasets -q            # Hugging Face datasets


# !python -m spacy download en_core_web_sm

print("✅ All packages installed successfully!")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 103.0 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ✅ All packages installed successfully!

# %%
# Test pdfplumber
import pdfplumber
print("✅ pdfplumber working")

# Test spaCy + model
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("This agreement is between John and ABC Company on 1st January 2025.")
print("✅ spaCy working")
print("   Entities found:", [(ent.text, ent.label_) for ent in doc.ents])

# Test transformers
from transformers import pipeline
print("✅ transformers working")

# Test sentence transformers
from sentence_transformers import SentenceTransformer
print("✅ sentence-transformers working")

# Test chromadb
import chromadb
print("✅ chromadb working")

# Test anthropic
import anthropic
print("✅ anthropic working")

# Test fpdf
from fpdf import FPDF
print("✅ fpdf2 working")

print("\n ALL PACKAGES VERIFIED — Ready to build!")
# Out:
# ✅ pdfplumber working
# ✅ spaCy working
#    Entities found: [('John', 'PERSON'), ('ABC Company', 'ORG'), ('1st January 2025', 'DATE')]
# ✅ transformers working
# ✅ sentence-transformers working
# ✅ chromadb working
# ✅ anthropic working
# ✅ fpdf2 working
#
# 🎉 ALL PACKAGES VERIFIED — Ready to build!

# %%
# CELL 2 — Mount with forced re-authentication

from google.colab import drive

# Force=True makes it ask for login again fresh
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

DOCS_FOLDER   = "/content/drive/MyDrive/legal_analyzer/documents/"
MODELS_FOLDER = "/content/drive/MyDrive/legal_analyzer/models/"
DB_FOLDER     = "/content/drive/MyDrive/legal_analyzer/chromadb/"
OUTPUT_FOLDER = "/content/drive/MyDrive/legal_analyzer/outputs/"

for folder in [DOCS_FOLDER, MODELS_FOLDER, DB_FOLDER, OUTPUT_FOLDER]:
    os.makedirs(folder, exist_ok=True)
    print(f"✅ Ready: {folder}")

print("\n All folders created on Google Drive!")
# Out:
# ✅ Ready: /content/drive/MyDrive/legal_analyzer/documents/
# ✅ Ready: /content/drive/MyDrive/legal_analyzer/models/
# ✅ Ready: /content/drive/MyDrive/legal_analyzer/chromadb/
# ✅ Ready: /content/drive/MyDrive/legal_analyzer/outputs/
#
# 🎉 All folders created on Google Drive!

# %%
from google.colab import drive
import os


drive.mount('/content/drive', force_remount=True)
print("✅ Drive mounted!")


DOCS_FOLDER   = "/content/drive/MyDrive/legal_analyzer/documents/"
MODELS_FOLDER = "/content/drive/MyDrive/legal_analyzer/models/"
DB_FOLDER     = "/content/drive/MyDrive/legal_analyzer/chromadb/"
OUTPUT_FOLDER = "/content/drive/MyDrive/legal_analyzer/outputs/"


for folder in [DOCS_FOLDER, MODELS_FOLDER, DB_FOLDER, OUTPUT_FOLDER]:
    os.makedirs(folder, exist_ok=True)
    print(f"✅ Ready: {folder}")


print("\n📁 Files in documents folder:")
print("=" * 50)
files = os.listdir(DOCS_FOLDER)
if files:
    for i, file in enumerate(files):
        size = os.path.getsize(DOCS_FOLDER + file)
        print(f"{i+1}. {file}  ({size} bytes)")
else:
    print("⚠️ Folder is empty — PDF not found here")
# Out:
# Mounted at /content/drive
# ✅ Drive mounted!
# ✅ Ready: /content/drive/MyDrive/legal_analyzer/documents/
# ✅ Ready: /content/drive/MyDrive/legal_analyzer/models/
# ✅ Ready: /content/drive/MyDrive/legal_analyzer/chromadb/
# ✅ Ready: /content/drive/MyDrive/legal_analyzer/outputs/
#
# 📁 Files in documents folder:
# ==================================================
# 1. file 1.zip  (8904 bytes)
# 2. file2.zip  (107396194 bytes)
# 3. CUAD_v1  (4096 bytes)
# 4. CUAD_v1_README.txt  (26712 bytes)

# %%
# CELL — Extract ZIP files and find PDFs

import zipfile
import os

zip_files = ["file 1.zip", "file2.zip"]

print("📦 Extracting ZIP files...")
print("=" * 50)

for zip_name in zip_files:
    zip_path = DOCS_FOLDER + zip_name

    print(f"\n📂 Opening: {zip_name}")

    with zipfile.ZipFile(zip_path, 'r') as z:
        # Show what's inside
        contents = z.namelist()
        print(f"   Contains {len(contents)} files:")
        for item in contents[:10]:  # show first 10
            print(f"   • {item}")

        # Extract everything to documents folder
        z.extractall(DOCS_FOLDER)
        print(f"   ✅ Extracted successfully!")

# Now show all files including extracted ones
print("\n\n📁 ALL FILES after extraction:")
print("=" * 50)
for root, dirs, files in os.walk(DOCS_FOLDER):
    for file in files:
        if not file.endswith('.zip'):  # skip zips
            full_path = os.path.join(root, file)
            size = os.path.getsize(full_path)
            print(f"📄 {full_path}  ({size} bytes)")
# Out:
# 📦 Extracting ZIP files...
# ==================================================
#
# 📂 Opening: file 1.zip
#    Contains 1 files:
#    • CUAD_v1_README.txt
#    ✅ Extracted successfully!
#
# 📂 Opening: file2.zip
#    Contains 1051 files:
#    • CUAD_v1/CUAD_v1.json
#    • CUAD_v1/CUAD_v1_README.txt
#    • CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.pdf
#    • CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/CybergyHoldingsInc_20140520_10-Q_EX-10.27_8605784_EX-10.27_Affiliate Agreement.pdf
#    • CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/DigitalCinemaDestinationsCorp_20111220_S-1_EX-10.10_7346719_EX-10.10_Affiliate Agreement.pdf
#    • CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/LinkPlusCorp_20050802_8-K_EX-10_3240252_EX-10_Affiliate Agreement.pdf
#    • CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/SouthernStarEnergyInc_20051202_SB-2A_EX-9_801890_EX-9_Affiliate Agreement.pdf
#    • CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/SteelVaultCorp_20081224_10-K_EX-10.16_3074935_EX-10.16_Affiliate Agreement.pdf
bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/full_contract_txt/ZEBRATECHNOLOGIESCORP_04_16_2014-EX-10.1-INTELLECTUAL PROPERTY AGREEMENT.txt  (127208 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/full_contract_txt/ZogenixInc_20190509_10-Q_EX-10.2_11663313_EX-10.2_Distributor Agreement.txt  (175779 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/full_contract_txt/ZONDWINDSYSTEMPARTNERSLTDSERIES85-B_04_03_2006-EX-10-MANAGEMENT AND MAINTENANCE AGREEMENT.txt  (17712 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/full_contract_txt/Zounds Hearing, Inc. - MANUFACTURING DESIGN MARKETING AGREEMENT.txt  (47001 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/full_contract_txt/ZtoExpressCaymanInc_20160930_F-1_EX-10.10_9752871_EX-10.10_Transportation Agreement.txt  (9174 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Anti-assignment, CIC (Group 3).xlsx  (111477 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Audit Rights.xlsx  (89081 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Covenant not to Sue_ Release of Claims.xlsx  (36971 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Dates (Group 1).xlsx  (108160 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Document Name.xlsx  (34132 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Governing Law.xlsx  (55157 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Joint IP Ownership.xlsx  (25704 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - IP Ownership Assignment.xlsx  (57413 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Insurance.xlsx  (75416 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Licenses (Group 4).xlsx  (149265 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Liquidated Damages.xlsx  (28949 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Most Favored Nation.xlsx  (18276 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Minimum Commitment.xlsx  (69328 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - No-Solicit of Employees.xlsx  (23716 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Non-Disparagement.xlsx  (20713 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Parties.xlsx  (77388 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Non-Compete, Exclusivity, No-Solicit of Customers (Group 2).xlsx  (104803 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Post-Termination Services.xlsx  (87964 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Price Restrictions.xlsx  (14734 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - ROFR-ROFO-ROFN.xlsx  (59910 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Revenue-Profit Sharing.xlsx  (66135 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Source Code Escrow.xlsx  (21872 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Termination for Convenience.xlsx  (36151 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Third Party Beneficiary.xlsx  (15194 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Uncapped Liability (Group 5).xlsx  (120750 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Unlimited-All-You-Can-Eat License.xlsx  (19940 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Volume Restriction.xlsx  (32477 bytes)
# 📄 /content/drive/MyDrive/legal_analyzer/documents/CUAD_v1/label_group_xlsx/Label Report - Warranty Duration.xlsx  (33405 bytes)

# %%
# CELL 4 — Read a contract from CUAD dataset
# We use TXT files directly — no PDF parsing needed!

import os

# Path to all text contracts
TXT_FOLDER = DOCS_FOLDER + "CUAD_v1/full_contract_txt/"

# List all available contracts
all_contracts = os.listdir(TXT_FOLDER)
print(f"✅ Total contracts available: {len(all_contracts)}")
print("\n📄 First 10 contracts:")
for i, name in enumerate(all_contracts[:10]):
    print(f"  {i}. {name}")
# Out:
# ✅ Total contracts available: 510
#
# 📄 First 10 contracts:
#   0. 2ThemartComInc_19990826_10-12G_EX-10.10_6700288_EX-10.10_Co-Branding Agreement_ Agency Agreement.txt
#   1. ACCELERATEDTECHNOLOGIESHOLDINGCORP_04_24_2003-EX-10.13-JOINT VENTURE AGREEMENT.txt
#   2. ABILITYINC_06_15_2020-EX-4.25-SERVICES AGREEMENT.txt
#   3. ACCURAYINC_09_01_2010-EX-10.31-DISTRIBUTOR AGREEMENT.txt
#   4. ADAMSGOLFINC_03_21_2005-EX-10.17-ENDORSEMENT AGREEMENT.txt
#   5. ADAPTIMMUNETHERAPEUTICSPLC_04_06_2017-EX-10.11-STRATEGIC ALLIANCE AGREEMENT.txt
#   6. ADIANUTRITION,INC_04_01_2005-EX-10.D2-RESELLER AGREEMENT.txt
#   7. ADMA BioManufacturing, LLC -  Amendment 3 to Manufacturing Agreement.txt
#   8. ADUROBIOTECH,INC_06_02_2020-EX-10.7-CONSULTING AGREEMENT(1).txt
#   9. ADUROBIOTECH,INC_06_02_2020-EX-10.7-CONSULTING AGREEMENT.txt

# %%
# CELL 4B — Pick one contract and read it

# We'll use a simple Affiliate Agreement for testing
# Small file = faster to process

chosen_file = "CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.txt"

file_path = TXT_FOLDER + chosen_file

# Read the text file directly
with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
    clean = f.read()

# Show basic stats
words = clean.split()
print(f"✅ Contract loaded successfully!")
print(f"📄 File: {chosen_file}")
print(f"📊 Total characters : {len(clean)}")
print(f"📊 Total words      : {len(words)}")

# Preview first 500 characters
print(f"\n📋 FIRST 500 CHARACTERS:")
print("=" * 50)
print(clean[:500])
print("=" * 50)

# Save path for use in later cells
CONTRACT_TEXT = clean
CONTRACT_NAME = chosen_file
print(f"\n✅ CONTRACT_TEXT variable is ready for next modules!")
# Out:
# ✅ Contract loaded successfully!
# 📄 File: CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.txt
# 📊 Total characters : 28804
# 📊 Total words      : 4045
#
# 📋 FIRST 500 CHARACTERS:
# ==================================================
# Exhibit 10.33   Last Updated: April 6, 2007     CHASE AFFILIATE AGREEMENT   THIS AGREEMENT sets forth the terms and conditions agreed to between Chase Bank USA, N.A. (?Chase?) and you as an "Affiliate" in the Chase Affiliate Program (the "Affiliate Program"). Once accepted into the Affiliate Program, an Affiliate can establish links from the Affiliate's Website to [Chase.com]. Chase will pay Affiliate a fee for each approved credit card account that originates from a link in Affiliate's Website.
# ==================================================
#
# ✅ CONTRACT_TEXT variable is ready for next modules!

# %%
# CELL 5A — Load spaCy model

import spacy

nlp = spacy.load("en_core_web_sm")
print("✅ spaCy model loaded!")
# Out:
# ✅ spaCy model loaded!

# %%
# CELL 5B — Extract Legal Entities

def extract_legal_entities(text):
    """
    Finds important legal entities from contract text.
    Processes in chunks because spaCy has a size limit.
    """
    all_entities = {}
    chunk_size = 100000

    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        doc = nlp(chunk)

        for ent in doc.ents:
            label = ent.label_
            value = ent.text.strip()

            # Only keep legally relevant entity types
            if label in ["PERSON", "ORG", "DATE", "MONEY",
                         "GPE", "LAW", "PERCENT", "CARDINAL"]:
                if label not in all_entities:
                    all_entities[label] = set()
                # Clean up: ignore very short or very long values
                if 2 < len(value) < 100:
                    all_entities[label].add(value)

    # Convert sets to sorted lists
    return {k: sorted(list(v)) for k, v in all_entities.items()}


def find_obligation_words(text):
    """
    Finds legal obligation keywords and counts them.
    These words tell us what parties MUST or MUST NOT do.
    """
    obligations = [
        "shall", "must", "is required to",
        "agrees to", "undertakes to",
        "will not", "shall not", "may not",
        "is obligated to", "is prohibited from"
    ]

    text_lower = text.lower()
    found = {}
    for word in obligations:
        count = text_lower.count(word)
        if count > 0:
            found[word] = count

    # Sort by frequency
    return dict(sorted(found.items(),
                key=lambda x: x[1], reverse=True))


# ---- RUN ON OUR CONTRACT ----
print("🔍 Extracting entities from contract...\n")

entities = extract_legal_entities(CONTRACT_TEXT)
obligations = find_obligation_words(CONTRACT_TEXT)

# Display entities
print("👥 LEGAL ENTITIES FOUND:")
print("=" * 50)

entity_labels = {
    "ORG":     "🏢 Organizations",
    "PERSON":  "👤 People",
    "DATE":    "📅 Dates",
    "MONEY":   "💰 Money",
    "GPE":     "📍 Locations",
    "LAW":     "⚖️  Laws",
    "PERCENT": "📊 Percentages",
    "CARDINAL": "🔢 Numbers"
}

for label, values in entities.items():
    friendly = entity_labels.get(label, label)
    print(f"\n{friendly}:")
    for v in values[:5]:  # show top 5 of each
        print(f"  • {v}")

print("\n\n⚖️  OBLIGATION WORDS FREQUENCY:")
print("=" * 50)
for word, count in obligations.items():
    bar = "█" * min(count, 20)
    print(f"  '{word}': {bar} ({count}x)")
# Out:
# 🔍 Extracting entities from contract...
#
# 👥 LEGAL ENTITIES FOUND:
# ==================================================
#
# 🔢 Numbers:
#   • 10.33
#   • 5.Term
#   • 8/10/2007
#   • at least seven
#   • five
#
# 📅 Dates:
#   • 7) days
#   • 8/10/2007
#   • April 6, 2007
#   • monthly
#
# 🏢 Organizations:
#   • AARP
#   • AARP Insurance
#   • AARPhealthcare.com
#   • Affiliate
#   • Affiliate Program
#
# 📍 Locations:
#   • 8/10/2007
#   • Amerada
#   • Crowne Plaza
#   • Marriott
#   • N.A.
#
# 👤 People:
#   • AGREES
#   • Appendix
#   • Candlewood Suites
#   • Linkshare Network
#   • Mar
#
# 💰 Money:
#   • 55.00
#
# ⚖️  Laws:
#   • section 4
#   • the "Marks
#
#
# ⚖️  OBLIGATION WORDS FREQUENCY:
# ==================================================
#   'shall': ███████████ (11x)
#   'will not': █████ (5x)
#   'must': ████ (4x)
#   'agrees to': ████ (4x)
#   'may not': ████ (4x)
#   'shall not': ██ (2x)
#   'is prohibited from': █ (1x)

# %%
# CELL 5C — Extract Key Contract Information

def extract_contract_summary(text, entities):
    """
    Uses extracted entities to build a structured
    summary of the contract's key information.
    """

    print("📋 CONTRACT KEY INFORMATION")
    print("=" * 50)

    # Document type from filename
    print(f"\n📄 Document: {CONTRACT_NAME}")

    # Parties involved
    orgs = entities.get("ORG", [])
    if orgs:
        print(f"\n🏢 PARTIES INVOLVED ({len(orgs)} organizations):")
        for org in orgs[:5]:
            print(f"   • {org}")

    # Important dates
    dates = entities.get("DATE", [])
    if dates:
        print(f"\n📅 KEY DATES MENTIONED ({len(dates)} found):")
        for date in dates[:5]:
            print(f"   • {date}")

    # Money amounts
    money = entities.get("MONEY", [])
    if money:
        print(f"\n💰 FINANCIAL TERMS ({len(money)} found):")
        for m in money[:5]:
            print(f"   • {m}")

    # Locations/Jurisdiction
    locations = entities.get("GPE", [])
    if locations:
        print(f"\n📍 LOCATIONS/JURISDICTION:")
        for loc in locations[:5]:
            print(f"   • {loc}")

    # Laws mentioned
    laws = entities.get("LAW", [])
    if laws:
        print(f"\n⚖️  LAWS REFERENCED:")
        for law in laws[:5]:
            print(f"   • {law}")

    print("\n" + "=" * 50)
    print("✅ Entity extraction complete!")


extract_contract_summary(CONTRACT_TEXT, entities)
# Out:
# 📋 CONTRACT KEY INFORMATION
# ==================================================
#
# 📄 Document: CreditcardscomInc_20070810_S-1_EX-10.33_362297_EX-10.33_Affiliate Agreement.txt
#
# 🏢 PARTIES INVOLVED (155 organizations):
#    • AARP
#    • AARP Insurance
#    • AARPhealthcare.com
#    • Affiliate
#    • Affiliate Program
#
# 📅 KEY DATES MENTIONED (4 found):
#    • 7) days
#    • 8/10/2007
#    • April 6, 2007
#    • monthly
#
# 💰 FINANCIAL TERMS (1 found):
#    • 55.00
#
# 📍 LOCATIONS/JURISDICTION:
#    • 8/10/2007
#    • Amerada
#    • Crowne Plaza
#    • Marriott
#    • N.A.
#
# ⚖️  LAWS REFERENCED:
#    • section 4
#    • the "Marks
#
# ==================================================
# ✅ Entity extraction complete!

# %%
# CELL 6A — Split contract into clauses

import re

def split_into_clauses(text):
    """
    Splits contract into individual clauses.
    Legal contracts use numbered sections like:
    1. Something
    2. Something else
    1.1 Sub clause
    """

    # Split by numbered patterns
    clauses = re.split(
        r'\n(?=\s*\d+[\.\)]\s+[A-Z])',
        text
    )

    # Clean each clause
    cleaned = []
    for clause in clauses:
        clause = clause.strip()
        # Keep only meaningful clauses (not too short)
        if len(clause) > 80:
            cleaned.append(clause)

    print(f"✅ Found {len(cleaned)} clauses in contract")
    print("\n📋 FIRST 3 CLAUSES PREVIEW:")
    print("=" * 50)
    for i, clause in enumerate(cleaned[:3]):
        print(f"\n--- CLAUSE {i+1} ---")
        print(clause[:200])
        print("...")

    return cleaned


# Run it
clauses = split_into_clauses(CONTRACT_TEXT)
# Out:
# ✅ Found 4 clauses in contract
#
# 📋 FIRST 3 CLAUSES PREVIEW:
# ==================================================
#
# --- CLAUSE 1 ---
# Exhibit 10.33   Last Updated: April 6, 2007     CHASE AFFILIATE AGREEMENT   THIS AGREEMENT sets forth the terms and conditions agreed to between Chase Bank USA, N.A. (?Chase?) and you as an "Affiliate
# ...
#
# --- CLAUSE 2 ---
# 7. Order Processing   Chase will be solely responsible for processing each order placed by a customer from Affiliate's Links. Customers may only use the Chase on-line application process to apply for
# ...
#
# --- CLAUSE 3 ---
# 13. Commercial Use   This program is intended for commercial use only. Commissions are payable for Approved Accounts to third parties who access the Chase URL's (marketing pages) through the Links loc
# ...

# %%
# CELL 6B — Risk Classifier using Groq (Updated)

from groq import Groq
import os
import time

client = Groq(api_key=os.environ["GROQ_API_KEY"])

def classify_clause_risk(clause_text):
    """
    Sends each clause to Groq LLM and gets:
    1. Risk level (Safe / Caution / High Risk)
    2. Risk type
    3. Plain English explanation
    """

    prompt = f"""You are a legal contract risk analyzer.
Analyze this contract clause and respond in EXACTLY this format:

RISK_LEVEL: [Safe / Caution / High Risk]
RISK_TYPE: [one short phrase describing the risk type]
EXPLANATION: [one plain English sentence explaining why]

Contract clause:
{clause_text[:600]}"""

    try:
        response = client.chat.completions.create(
            model="llama-3.1-8b-instant",
            messages=[{"role": "user", "content": prompt}]
        )

        result_text = response.choices[0].message.content.strip()

        # Parse response
        lines = result_text.split('\n')
        risk_level  = "Unknown"
        risk_type   = "Unknown"
        explanation = "Unable to parse"

        for line in lines:
            if line.startswith("RISK_LEVEL:"):
                risk_level = line.replace("RISK_LEVEL:", "").strip()
            elif line.startswith("RISK_TYPE:"):
                risk_type = line.replace("RISK_TYPE:", "").strip()
            elif line.startswith("EXPLANATION:"):
                explanation = line.replace("EXPLANATION:", "").strip()

        # Add emoji
        if "High Risk" in risk_level:
            emoji = "🔴"
        elif "Caution" in risk_level:
            emoji = "🟡"
        else:
            emoji = "🟢"

        return {
            "risk_level": f"{emoji} {risk_level}",
            "risk_type": risk_type,
            "explanation": explanation
        }

    except Exception as e:
        return {
            "risk_level": "⚠️ Error",
            "risk_type": "API Error",
            "explanation": str(e)
        }


# Test on first clause
print("🔍 Testing risk classifier...\n")
test = classify_clause_risk(clauses[0])
print(f"Risk Level  : {test['risk_level']}")
print(f"Risk Type   : {test['risk_type']}")
print(f"Explanation : {test['explanation']}")
print("\n✅ Classifier working!")
# Out:
# 🔍 Testing risk classifier...
#
# Risk Level  : 🟡 Caution
# Risk Type   : Contract Obligation
# Explanation : This clause creates a binding contractual agreement between the Affiliate and Chase, which may limit the Affiliate's future flexibility or create financial obligations.
#
# ✅ Classifier working!

# %%
# CELL 6C — Analyze ALL clauses

print("⚖️  ANALYZING ALL CLAUSES FOR RISK...")
print("=" * 60)

risk_results = []
high_risk_count = 0
caution_count   = 0
safe_count      = 0

for i, clause in enumerate(clauses[:10]):
    print(f"Analyzing clause {i+1}/{min(10, len(clauses))}...",
          end=" ")

    result = classify_clause_risk(clause)
    result["clause_text"]   = clause[:200]
    result["clause_number"] = i + 1
    risk_results.append(result)

    print(result['risk_level'])
    time.sleep(0.5)  # small delay

# Full report
print("\n\n📊 FULL RISK ANALYSIS REPORT:")
print("=" * 60)

for r in risk_results:
    print(f"\nClause {r['clause_number']}: {r['risk_level']}")
    print(f"  Type       : {r['risk_type']}")
    print(f"  Explanation: {r['explanation']}")
    print(f"  Text       : {r['clause_text'][:100]}...")

    if "High Risk" in r['risk_level']:
        high_risk_count += 1
    elif "Caution" in r['risk_level']:
        caution_count += 1
    else:
        safe_count += 1

print("\n" + "=" * 60)
print("📈 RISK SUMMARY:")
print(f"  🔴 High Risk : {high_risk_count}")
print(f"  🟡 Caution   : {caution_count}")
print(f"  🟢 Safe      : {safe_count}")
print(f"  📄 Total     : {len(risk_results)}")
print("=" * 60)
print("\n✅ Phase 4 Complete!")
# Out:
# ⚖️  ANALYZING ALL CLAUSES FOR RISK...
# ============================================================
# Analyzing clause 1/4... 🟡 Caution
# Analyzing clause 2/4... 🟡 Caution
# Analyzing clause 3/4... 🔴 High Risk
# Analyzing clause 4/4... 🔴 High Risk
#
#
# 📊 FULL RISK ANALYSIS REPORT:
# ============================================================
#
# Clause 1: 🟡 Caution
#   Type       : Contract Interpretation
#   Explanation: This clause presents a risk as it may be interpreted that the Affiliate Program is a one-sided contract where Chase's terms and conditions could be used to exploit or bind the Affiliate in unforeseen ways.
#   Text       : Exhibit 10.33   Last Updated: April 6, 2007     CHASE AFFILIATE AGREEMENT   THIS AGREEMENT sets fort...
#
# Clause 2: 🟡 Caution
#   Type       : Vendor Dependence
#   Explanation: The affiliate relies heavily on Chase for order processing, customer service, and related rules and policies, which may shift liability from the affiliate to Chase in case of errors or disputes, but may also limit the affiliate's flexibility and control over the customer experience.
#   Text       : 7. Order Processing   Chase will be solely responsible for processing each order placed by a custome...
#
# Clause 3: 🔴 High Risk
#   Type       : Loss of Exclusive Rights
#   Explanation: Chase's reservation of full ownership of its trademarks could potentially be used to restrict or terminate an affiliate's rights to use these marks, exposing affiliates to significant financial losses.
#   Text       : 13. Commercial Use   This program is intended for commercial use only. Commissions are payable for A...
#
# Clause 4: 🔴 High Risk
#   Type       : Unlimited Liability Cap
#   Explanation: The clause limits Chase's total liability to the total commissions paid to the affiliate, which could leave the affiliate with significant financial losses in case of damages, as they won't be able to recover any more than the commissions earned.
#   Text       : 21. Limitation of Damages   Chase shall have no liability for any indirect, incidental, special or c...
#
# ============================================================
# 📈 RISK SUMMARY:
#   🔴 High Risk : 2
#   🟡 Caution   : 2
#   🟢 Safe      : 0
#   📄 Total     : 4
# ============================================================
#
# ✅ Phase 4 Complete!

# %%
# Install Groq
# !pip install groq -q

from google.colab import userdata
from groq import Groq
import os

# Load key
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# Create client
client = Groq(api_key=os.environ["GROQ_API_KEY"])

# Test it
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",  # free and fast model
    messages=[
        {"role": "user",
         "content": "Say exactly: API is working!"}
    ]
)

print("✅ SUCCESS!")
print(response.choices[0].message.content)
# Out:
# ✅ SUCCESS!
# API is working!

# %%
# CELL 8 — Plain Language Summarizer using Groq

def summarize_in_plain_english(text, doc_type="legal contract"):
    """
    Sends contract to Groq and gets back a
    plain English summary anyone can understand.
    """

    prompt = f"""You are a legal document simplifier.
Read this {doc_type} and explain it in plain simple English
that a non-lawyer can understand.

Structure your response EXACTLY like this:

WHAT IS THIS: (one sentence describing the document)
KEY PARTIES: (who is involved)
MAIN OBLIGATIONS: (what each party must do)
IMPORTANT DATES: (key deadlines and durations)
MONEY INVOLVED: (all financial terms)
WATCH OUT FOR: (3 things the reader should be careful about)
SIMPLE SUMMARY: (2-3 sentence plain English summary)

Legal document:
{text[:3000]}"""

    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[{"role": "user", "content": prompt}]
    )

    return response.choices[0].message.content


# Run summarizer
print("📝 Generating plain English summary...")
print("=" * 60)

summary = summarize_in_plain_english(CONTRACT_TEXT,
                                      "affiliate agreement")
print(summary)
print("=" * 60)
print("\n✅ Phase 5 Complete!")

# Save summary for report later
CONTRACT_SUMMARY = summary
# Out:
# 📝 Generating plain English summary...
# ============================================================
# WHAT IS THIS: This document is a contract between Chase Bank and an individual or company (known as an affiliate) that wants to be part of Chase's affiliate program, where they can promote Chase's financial services and earn a fee for each new customer that joins after clicking on a link from the affiliate's website.
#
# KEY PARTIES:
# - Chase Bank USA, N.A. (Chase)
# - The individual or company (known as an affiliate) who wants to join the Chase affiliate program
#
# MAIN OBLIGATIONS:
# - The affiliate must submit a registration form and agree to the terms of the contract.
# - Chase will evaluate the registration form and can accept or reject the affiliate's application.
# - The affiliate must ensure their website does not contain any "restricted content" (such as profanity, violence, or intellectual property infringement) that could make their site unsuitable for the affiliate program.
# - Chase will pay the affiliate a fee for each new credit card account that originates from the affiliate's website.
#
# IMPORTANT DATES:
# - The contract will start when Chase accepts the affiliate's registration form and notifies them via email.
# - There is no specified end date or duration for the contract, but Chase reserves the right to terminate it if the affiliate's website contains restricted content.
#
# MONEY INVOLVED:
# - Chase will pay the affiliate a fee for each new credit card account that originates from the affiliate's website.
# - The contract does not specify the exact amount of the fee or how it will be calculated.
#
# WATCH OUT FOR:
# - Chase can accept or reject the affiliate's application, and it's not clear how they will evaluate the application or what factors they will consider.
# - The affiliate must ensure their website complies with the "restricted content" guidelines, which could be subject to interpretation.
# - Chase can terminate the contract at any time if the affiliate's website contains restricted content, which could result in lost income for the affiliate.
#
# SIMPLE SUMMARY:
# This contract establishes a partnership between Chase Bank and an affiliate where the affiliate promotes Chase's financial services on their website and earns a fee for each new customer that joins. The affiliate must ensure their website complies with specific guidelines, and Chase reserves the right to accept or reject the application and terminate the contract if these guidelines are not followed.
# ============================================================
#
# ✅ Phase 5 Complete!

# %%
# Check what variable your extracted text is stored in
# Run this to see all available text variables

print(type(clean))      # should say <class 'str'>
print(len(clean))       # should show character count
print(clean[:200])      # preview first 200 chars
# Out:
# <class 'str'>
# 28804
# Exhibit 10.33   Last Updated: April 6, 2007     CHASE AFFILIATE AGREEMENT   THIS AGREEMENT sets forth the terms and conditions agreed to between Chase Bank USA, N.A. (?Chase?) and you as an "Affiliate

# %%
# CELL 9 — Setup Vector Database for Q&A

# !pip install sentence-transformers chromadb -q

from sentence_transformers import SentenceTransformer
import chromadb
import os

print("Loading embedding model...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
print("✅ Embedding model loaded!")

# FIX: Use local Colab storage instead of Google Drive
LOCAL_DB_FOLDER = "/content/chromadb/"
os.makedirs(LOCAL_DB_FOLDER, exist_ok=True)

chroma_client = chromadb.PersistentClient(path=LOCAL_DB_FOLDER)
print("✅ ChromaDB initialized!")

# Create fresh collection
try:
    chroma_client.delete_collection("legal_doc")
except:
    pass

collection = chroma_client.create_collection("legal_doc")

def chunk_text(text, chunk_size=500, overlap=50):
    """Splits text into overlapping chunks"""
    words = text.split()
    chunks = []
    for i in range(0, len(words), chunk_size - overlap):
        chunk = " ".join(words[i:i+chunk_size])
        if len(chunk) > 100:
            chunks.append(chunk)
    return chunks

def index_document(text):
    """Converts document into embeddings and stores in ChromaDB"""
    chunks = chunk_text(text)
    print(f"📦 Indexing {len(chunks)} chunks...")

    embeddings = embedder.encode(chunks).tolist()

    collection.add(
        documents=chunks,
        embeddings=embeddings,
        ids=[f"chunk_{i}" for i in range(len(chunks))]
    )
    print(f"✅ Document indexed successfully!")
    return len(chunks)

# Index our contract
index_document(CONTRACT_TEXT)
# Out:
# Loading embedding model...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Embedding model loaded!
# ✅ ChromaDB initialized!
# 📦 Indexing 9 chunks...
# ✅ Document indexed successfully!
# 9

# %%
# CELL 10 — Q&A Function + Test (Fixed)

def answer_question(question):
    # Step 1: Embed question
    question_embedding = embedder.encode([question]).tolist()

    # Step 2: Find relevant chunks
    results = collection.query(
        query_embeddings=question_embedding,
        n_results=3
    )
    relevant_chunks = "\n\n".join(results['documents'][0])

    # Step 3: Ask Groq with context
    prompt = f"""You are a legal document assistant.
Answer the question based ONLY on the document excerpts below.
If the answer is not in the document say:
This information is not mentioned in the document.
Be concise and clear. Avoid legal jargon.

DOCUMENT EXCERPTS:
{relevant_chunks}

QUESTION: {question}

ANSWER:"""

    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[{"role": "user", "content": prompt}]
    )

    return response.choices[0].message.content.strip()


# Test questions
print("💬 DOCUMENT Q&A TEST")
print("=" * 60)

test_questions = [
    "Who are the parties involved in this agreement?",
    "What happens if I put restricted content on my website?",
    "How does Chase pay the affiliate?",
    "Can Chase terminate this agreement?"
]

for question in test_questions:
    print(f"\n❓ {question}")
    answer = answer_question(question)
    print(f"💡 {answer}")
    print("-" * 40)

print("\n✅ Phase 6 Complete!")
# Out:
# 💬 DOCUMENT Q&A TEST
# ============================================================
#
# ❓ Who are the parties involved in this agreement?
# 💡 Chase and Affiliate are the parties involved in this agreement.
#
# Specifically, the document references "Chase, Customer or Affiliate" and "the other party hereto," indicating that Chase and Affiliate are the primary parties. The term "Customer" may also refer to a third party involved in the Chase Affiliate Program, but Chase and Affiliate are the main parties signing the agreement.
# ----------------------------------------
#
# ❓ What happens if I put restricted content on my website?
# 💡 This information is not mentioned in the document.
# ----------------------------------------
#
# ❓ How does Chase pay the affiliate?
# 💡 Chase pays the affiliate a "Commission" for each "Approved Account" made through the affiliate's site. The Commission is calculated according to a tiered or flat schedule set forth in the agreement, based on private offer terms in the network.
#
# More specifically, Chase provides the affiliate with statements of Approved Account activity at the time Commissions are paid, and Affiliate will receive Commission payments for all Approved Accounts placed during the term of this Agreement.
# ----------------------------------------
#
# ❓ Can Chase terminate this agreement?
# 💡 According to the document excerpt in section 20, "Termination" Chase reserves the right to terminate this Agreement at any time in its sole discretion, upon written notice, which termination will be effective immediately upon such notice.
# ----------------------------------------
#
# ✅ Phase 6 Complete!

# %%
# CELL 11 — PDF Report Generator (Complete Fixed Version)

# !pip install fpdf2 -q

from fpdf import FPDF
import datetime
import os

def clean_str(text):
    return str(text).encode('latin-1', errors='replace').decode('latin-1')

def generate_report(doc_name, entities, risk_results, summary, output_path):
    pdf = FPDF()
    pdf.add_page()

    # HEADER
    pdf.set_fill_color(30, 30, 80)
    pdf.set_text_color(255, 255, 255)
    pdf.set_font("Helvetica", "B", 18)
    pdf.cell(0, 15, "Legal Document Analysis Report", new_x="LMARGIN", new_y="NEXT", align="C", fill=True)

    pdf.set_text_color(0, 0, 0)
    pdf.set_font("Helvetica", "", 10)
    pdf.cell(0, 7, clean_str("Document: " + doc_name[:60]), new_x="LMARGIN", new_y="NEXT")
    pdf.cell(0, 7, "Generated: " + datetime.datetime.now().strftime('%d %b %Y %H:%M'), new_x="LMARGIN", new_y="NEXT")
    pdf.ln(4)

    # RISK OVERVIEW
    high = sum(1 for r in risk_results if "High" in r.get('risk_level', ''))
    caut = sum(1 for r in risk_results if "Caution" in r.get('risk_level', ''))
    safe = sum(1 for r in risk_results if "Safe" in r.get('risk_level', ''))

    pdf.set_fill_color(240, 240, 240)
    pdf.set_font("Helvetica", "B", 12)
    pdf.cell(0, 10, "Risk Overview", new_x="LMARGIN", new_y="NEXT", fill=True)
    pdf.set_font("Helvetica", "", 11)
    pdf.cell(60, 8, "High Risk: " + str(high), new_x="RIGHT", new_y="TOP")
    pdf.cell(60, 8, "Caution: " + str(caut), new_x="RIGHT", new_y="TOP")
    pdf.cell(60, 8, "Safe: " + str(safe), new_x="LMARGIN", new_y="NEXT")
    pdf.ln(4)

    # ENTITIES
    pdf.set_fill_color(200, 220, 255)
    pdf.set_font("Helvetica", "B", 12)
    pdf.cell(0, 10, "Key Entities Identified", new_x="LMARGIN", new_y="NEXT", fill=True)
    pdf.set_font("Helvetica", "", 10)

    for label, values in entities.items():
        if values:
            pdf.set_font("Helvetica", "B", 10)
            pdf.cell(0, 6, str(label) + ":", new_x="LMARGIN", new_y="NEXT")
            pdf.set_font("Helvetica", "", 10)
            for v in list(values)[:3]:
                pdf.cell(10)
                pdf.cell(0, 6, clean_str("- " + str(v)), new_x="LMARGIN", new_y="NEXT")
    pdf.ln(4)

    # RISK CLAUSES
    pdf.set_fill_color(255, 200, 200)
    pdf.set_font("Helvetica", "B", 12)
    pdf.cell(0, 10, "Clause Risk Analysis", new_x="LMARGIN", new_y="NEXT", fill=True)

    for i, r in enumerate(risk_results[:10]):
        level = r.get('risk_level', 'Unknown')
        rtype = r.get('risk_type', 'Unknown')
        line  = "Clause " + str(i+1) + ": " + str(level) + " | " + str(rtype)
        pdf.set_font("Helvetica", "B", 9)
        pdf.cell(0, 6, clean_str(line), new_x="LMARGIN", new_y="NEXT")

        explanation = r.get('explanation', '')
        if explanation:
            pdf.set_font("Helvetica", "", 8)
            pdf.multi_cell(0, 5, clean_str(explanation[:200]))
        pdf.ln(2)
    pdf.ln(4)

    # SUMMARY
    pdf.set_fill_color(200, 255, 200)
    pdf.set_font("Helvetica", "B", 12)
    pdf.cell(0, 10, "Plain Language Summary", new_x="LMARGIN", new_y="NEXT", fill=True)
    pdf.set_font("Helvetica", "", 10)
    pdf.multi_cell(0, 6, clean_str(summary[:2000]))

    # SAVE
    pdf.output(output_path)
    print("Report saved to: " + output_path)


# RUN
report_path = "/content/legal_analysis_report.pdf"

generate_report(
    doc_name     = "contract.pdf",
    entities     = entities,
    risk_results = risk_results,
    summary      = summary,
    output_path  = report_path
)

# VERIFY AND DOWNLOAD
if os.path.exists(report_path):
    size = os.path.getsize(report_path)
    print("File confirmed - " + str(size) + " bytes")
    from google.colab import files
    files.download(report_path)
    print("Download started - check your Downloads folder!")
else:
    print("File not created - paste any error above")
# Out:
# Report saved to: /content/legal_analysis_report.pdf
# File confirmed - 3889 bytes
# Download started - check your Downloads folder!
